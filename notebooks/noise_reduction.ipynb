# %%
import IPython
from scipy.io import wavfile
import noisereduce as nr
import soundfile as sf
from noisereduce.generate_noise import band_limited_noise
import matplotlib.pyplot as plt
import urllib.request
import numpy as np
import librosa
import io

import pandas as pd
import matplotlib.pyplot as plt
import librosa
from librosa.display import specshow
import os
import numpy as np
n_fft=2048
dpi =400
duration = 5
sr = 44100
fmax = 800

# %matplotlib inline

# %%
os.getcwd()
# Out:
# '/Users/ryan/cloud/Workspace/trash-can-detector/notebooks'

# %%
sr = 44100
duration = 5
y,sr =librosa.load('../4d654bea-eae5-446e-9273-11ca8ed3522b.wav',sr=sr,offset=0,duration = duration,mono=True)
# [:sr*duration]
# Out:
# /Users/ryan/opt/anaconda3/envs/ml/lib/python3.8/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     148     try:
# --> 149         with sf.SoundFile(path) as sf_desc:
#     150             sr_native = sf_desc.samplerate
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
# ...

# %%
 duration = 4
 sr = 44100
# pitch = 'bang/455be475-19f8-4d07-a641-f64aa821672e.wav'
from os import listdir
from os.path import isfile, join

png_path='/Volumes/sambashare/astros/bangs/'
pngs = [f.split('.')[0] for f in listdir(png_path) if isfile(join(png_path, f))]

# %%
s.shape
# Out:
# (128, 215)

# %%
df = pd.read_csv('pitch_table.csv').set_index('pitch_id')
test=pd.DataFrame.from_dict({'pitch_id':df.index.values})

# %%
import file
import yaml
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-1d1e6b54fbd3> in <module>
# ----> 1 import file
#       2 import yaml
#
# ModuleNotFoundError: No module named 'file'

# %%
with open('../code/astros_config.yaml', 'r') as file:
    test=yaml.safe_load(file)

# %%
test['teams']
# Out:
# ['HOU']

# %%
a['test'] = 'f'

# %%
a
# Out:
#                                pitch_id test
# 1  1dd2e806-8a45-4433-a7fa-64b637537161    f
# 2  ef5299e9-c8af-4c49-bf89-0611c311e6f6    f
# 3  bb869a8d-d434-4ff1-8551-6d29f6ce86fb    f

# %%
n_fft=2048
dpi =400
duration = 5
sr = 44100
fmax = 2000

for p in pngs[70:80]:
    png_path='/Volumes/sambashare/astros/pitch_wavs/'



    y, sr = librosa.load(png_path+p+'.wav',sr=sr,offset=0,duration = duration)

    reduced_noise = nr.reduce_noise(y = y, sr=sr, n_std_thresh_stationary=0.5,stationary=True)

    s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,n_fft=int(16384/4),hop_length=int(4096/4),fmax=fmax)
    fig,ax = plt.subplots(1)
    ys,xs=s.shape
    fig.set_size_inches(xs/40, ys/40)
    fig.subplots_adjust(left=0,right=1,bottom=0,top=1)
    ax.axis('off')
    specshow(librosa.amplitude_to_db(s,ref=np.max),y_axis='mel', fmax=fmax,x_axis='time',ax=ax,cmap='gray_r')

    ax.set_axis_off()
    fig.add_axes(ax)
    print(p)
    fig.show()


    s = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128,n_fft=int(16384/4),hop_length=int(4096/4),fmax=fmax)
    fig,ax = plt.subplots(1)
    ys,xs=s.shape
    fig.set_size_inches(xs/40, ys/40)
    fig.subplots_adjust(left=0,right=1,bottom=0,top=1)
    ax.axis('off')
    specshow(librosa.amplitude_to_db(s,ref=np.max),y_axis='mel', fmax=fmax,x_axis='time',ax=ax,cmap='gray_r')

    ax.set_axis_off()
    fig.add_axes(ax)
    print(p)
    fig.show()

    # y, sr = librosa.load(png_path+p+'.wav',sr=sr,offset=0,duration = duration)

    # reduced_noise = nr.reduce_noise(y = y, sr=sr, n_std_thresh_stationary=0.5,stationary=True)

    # s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=64,n_fft=16384,hop_length=4096,fmax=fmax)
    # fig,ax = plt.subplots(1)
    # ys,xs=s.shape
    # fig.set_size_inches(xs/40, ys/40)
    # fig.subplots_adjust(left=0,right=1,bottom=0,top=1)
    # ax.axis('off')
    # specshow(librosa.amplitude_to_db(s,ref=np.max),y_axis='mel', fmax=fmax,x_axis='time',ax=ax,cmap='gray_r')

    # ax.set_axis_off()
    # fig.add_axes(ax)
    # print(p)
    # fig.show()



    # s = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=64,n_fft=16384,hop_length=4096,fmax=fmax)
    # fig,ax = plt.subplots(1)
    # ys,xs=s.shape
    # fig.set_size_inches(xs/40, ys/40)
    # fig.subplots_adjust(left=0,right=1,bottom=0,top=1)
    # ax.axis('off')
    # specshow(librosa.amplitude_to_db(s,ref=np.max),y_axis='mel', fmax=fmax,x_axis='time',ax=ax,cmap='gray_r')

    # ax.set_axis_off()
    # fig.add_axes(ax)
    # print(p)
    # fig.show()
# Out:
# 2f155c6a-4f3b-418d-8c72-f7b6983dbe24
# 2f155c6a-4f3b-418d-8c72-f7b6983dbe24
# <ipython-input-113-bcae73896d78>:27: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-113-bcae73896d78>:41: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# 0be2574f-53e7-42a0-9ac0-713f5ccc40e2
# 0be2574f-53e7-42a0-9ac0-713f5ccc40e2
# 1d0c3af5-815e-4e2f-9b59-fa17b362643b
# 1d0c3af5-815e-4e2f-9b59-fa17b362643b
# 0ac1c1fa-640a-4596-95d8-879c5abaefe6
# 0ac1c1fa-640a-4596-95d8-879c5abaefe6
# 2b994e9a-abbb-4325-9e4c-0bde2bc3c409
# 2b994e9a-abbb-4325-9e4c-0bde2bc3c409
# 0e8f3aad-d096-4466-8c0e-ce50aed88fd3
# 0e8f3aad-d096-4466-8c0e-ce50aed88fd3
# 2a97d3a7-3772-4cfc-b046-4491393dd137
# 2a97d3a7-3772-4cfc-b046-4491393dd137
# 0f6caad1-d3cb-43e2-b04b-351569efaea1
# ...

# %%
ys
# Out:
# 64

# %%
xs
# Out:
# 54

# %%
n_fft=2048
dpi =400
duration = 5
sr = 44100
fmax = 300

for p in pngs[50:60]:
    png_path='/Volumes/sambashare/astros/pitch_wavs/'
    y, sr = librosa.load(png_path+p+'.wav',sr=sr,offset=0,duration = duration)

    reduced_noise = nr.reduce_noise(y = y, sr=sr, n_std_thresh_stationary=0.1,stationary=True)

    s = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=64,n_fft=16384,hop_length=4096,fmax=fmax)
    fig,ax = plt.subplots(1)
    ys,xs=s.shape
    fig.set_size_inches(xs/40, ys/40)
    fig.subplots_adjust(left=0,right=1,bottom=0,top=1)
    ax.axis('off')
    specshow(librosa.amplitude_to_db(s,ref=np.max),y_axis='mel', fmax=fmax,x_axis='time',ax=ax,cmap='gray_r')

    ax.set_axis_off()
    fig.add_axes(ax)
    print(p)
    fig.show()
# Out:
# 1d3c9b6d-2e6f-4f19-baee-cfa13b34bbdb
# <ipython-input-78-f181e47500c8>:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# 1b7cfd5e-5de8-454b-92b8-73cc974764bd
# 2cc651d1-cb00-46d5-9515-66e2557bc47a
# 2c8bcc7d-86a0-4eae-88df-155e75085654
# 2b64fb88-99e0-4ea8-bc74-f56da40e64c9
# 2af56edb-5749-4b03-bfeb-3be0578b5106
# 0aa7e63c-444e-4efe-b749-6a60dfe55820
# 1ccdef9d-283f-4533-87cc-13bbdc774c4c
# 2eddabb0-b280-4dc4-af6d-33ab60790543
# 0e20e79c-04c0-4f22-9b5d-5c342fe302f8

# %%
fig, ax = plt.subplots(figsize=(20,3))
ax.plot(y)

# %%
fig, ax = plt.subplots(figsize=(20,3))
ax.plot(reduced_noise)

# %%
from scipy.io.wavfile import write

write("455be475-19f8-4d07-a641-f64aa821672e.wav", sr, reduced_noise)

# %%
reduced_noise = nr.reduce_noise(y = y, sr=sr, n_std_thresh_stationary=1.5,stationary=True)

# %%
n_fft=2048
dpi =400
duration = 5
sr = 44100
fmax = 800
s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,n_fft=15000,hop_length=800,fmax=fmax)
fig,ax = plt.subplots(1)
ys,xs=s.shape
fig.set_size_inches(xs/40, ys/40)
fig.subplots_adjust(left=0,right=1,bottom=0,top=1)
ax.axis('off')
specshow(librosa.amplitude_to_db(s,ref=np.max),y_axis='mel', fmax=fmax,x_axis='time',ax=ax,cmap='gray_r')

ax.set_axis_off()
fig.add_axes(ax)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Hz'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import librosa
from librosa.display import specshow
import os
import numpy as np

n_fft=2048
dpi =400
duration = 5
sr = 44100
fmax = 800
s = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128,n_fft=15000,hop_length=800,fmax=fmax)
fig,ax = plt.subplots(1)
ys,xs=s.shape
fig.set_size_inches(xs/40, ys/40)
fig.subplots_adjust(left=0,right=1,bottom=0,top=1)
ax.axis('off')
specshow(librosa.amplitude_to_db(s,ref=np.max),y_axis='mel', fmax=fmax,x_axis='time',ax=ax,cmap='gray_r')

ax.set_axis_off()
fig.add_axes(ax)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Hz'>

# %%
','.join(['test','jdksj'])
# Out:
# 'test,jdksj'
